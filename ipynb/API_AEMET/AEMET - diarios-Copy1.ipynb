# %% [markdown]
# # Datos climáticos diarios

# %% [markdown]
# Se generan las series climáticas diarias de las estaciones principales de la AEMET. Se pueden descargar todas las disponibles o por provincias. La duración de la serie también es definible

# %%
import requests

from requests.packages.urllib3.exceptions import InsecureRequestWarning
requests.packages.urllib3.disable_warnings(InsecureRequestWarning)

import pandas as pd
import numpy as np
import datetime
import time

# %%
# Ruta en la que está guardada la API key
ruta_API = "F:/Series/AEMET/apikey_AEMET.txt"
# Ruta donde se guardarán las series
#ruta_series = 'F:/Series/AEMET/Clima/Diario/'
ruta_series = 'F:/Series/AEMET/OpenData/Diario/Esla/'

# Definir el inicio y fin de la serie, y la duración de cada periodo
start_date = datetime.datetime(1950, 1, 1, 0, 0, 0)
final_date = datetime.datetime(2017, 11, 30, 23, 59, 59)

# Definir las estaciones: 'todas' o la lista de con los códigos
estaciones = ['2620E', '2621', '2622', '2624']

# %% [markdown]
# ## 1. Estaciones

# %%
def dms2dd(degrees, minutes, seconds, direction):
    """It converts a latitude or longitude value given in degrees, minutes, seconds and direction to decimal degrees
    """
    dd = float(degrees) + float(minutes)/60 + float(seconds)/(3600);
    if direction == 'W' or direction == 'S':
        dd *= -1
    return dd

# %%
# Carga la api key 
api_key = open(ruta_API).read().rstrip()
querystring = {"api_key": api_key}

# Obtenemos información de todas las estaciones disponibles
url = "https://opendata.aemet.es/opendata/api/valores/climatologicos/inventarioestaciones/todasestaciones"

# %%
# Realizamos la petición
r = requests.get(url, params=querystring, verify=False)

# %%
# Obtenemos el link del que descargaremos los datos
data_url = r.json()['datos']
r_data = requests.get(data_url, params=querystring, verify=False)

# %%
# Vemos el contenido
stations = r_data.json()

# %%
# Crea un data frame con las estaciones meteorológicas y sus características
n = len(stations)

columnas = []
for key in stations[0].keys():
    columnas.append(key)

stn_AEMET = pd.DataFrame(index=np.arange(n), columns=columnas)
stn_AEMET = stn_AEMET.loc[:, ['indicativo', 'nombre', 'provincia', 'indsinop',
                              'latitud', 'longitud', 'altitud']]

i = 0
for stn in stations:
    stn_AEMET.indicativo[i] = stn['indicativo']
    stn_AEMET.nombre[i] = stn['nombre']
    stn_AEMET.provincia[i] = stn['provincia']
    stn_AEMET.indsinop[i] = stn['indsinop']
    stn_AEMET.latitud[i] = dms2dd(stn['latitud'][:2], stn['latitud'][2:4], stn['latitud'][4:6], stn['latitud'][6])
    stn_AEMET.longitud[i] = dms2dd(stn['longitud'][:2], stn['longitud'][2:4], stn['longitud'][4:6], stn['longitud'][6])
    stn_AEMET.altitud[i] = int(stn['altitud'])
    i += 1
stn_AEMET.sort_values('indicativo', inplace=True)
stn_AEMET.set_index('indicativo', drop=True, inplace=True)

print('Nº de estaciones disponibles: ', stn_AEMET.shape[0])

stn_AEMET.head(2)
# Out:
# Nº de estaciones disponibles:  291
#                      nombre  provincia indsinop  latitud  longitud altitud
# indicativo
# 0002I           VANDELLÒS    TARRAGONA    08169  40.9581  0.871389      32
# 0016A       REUS AEROPUERTO  TARRAGONA    08175   41.145   1.16361      71

# %%
stn_AEMET.to_csv(ruta_series + 'estaciones_AEMET.csv', sep=',', na_rep='-100', header=True, index=True)

# %% [markdown]
# ## 2. Extraer datos diarios
#
# ### 2.1 Funciones

# %%
def parse_data(raw_data):
    """Convert from string to floating point number those columns in the data that represent quantitative variables"""
    data = []
    for d in raw_data:
        d = dict(d)  # Exto copia el parámetro
        for param in ['prec', 'presMax', 'presMin', 'racha', 'sol', 'tmax', 'tmed', 'tmin', 'velmedia', 'altitud', 'dir']:
            try:
                d[param] = float(d[param].replace(',', '.'))
            except:
                d[param] = None
        data.append(d)
    
    return data

# %%
def generate_dates(start_date, final_date, step):
    """It generates a list of dates beginning in the 'start_date', ending in the 'final_date' and every 'step' number of 
    dates"""
    
    chunks = [start_date]

    next_date = start_date + step
    while next_date < final_date:
        chunks.append(next_date)
        next_date += step

    chunks.append(final_date)

    return chunks

# %%
def extract_data(station, periodos):

    raw_data = []

    for ii in range(1, len(periodos)):
        print()
        print(station,
              " - ",
              periodos[ii-1].strftime('%Y-%m-%dT%H:%M:%SUTC'),
              " - ",
              periodos[ii].strftime('%Y-%m-%dT%H:%M:%SUTC'))

        url = ("https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/"
               "fechaini/{start}/fechafin/{end}/estacion/{station}".format(
                   start=periodos[ii-1].strftime('%Y-%m-%dT%H:%M:%SUTC'),
                    end=periodos[ii].strftime('%Y-%m-%dT%H:%M:%SUTC'),
                    station=station)
              )

        iterate = True

        while iterate:

            r = requests.get(url, params=querystring, verify=False)

            # Si no me deja hacer la conexión, la repito  
            iterate = (r.status_code == requests.codes.too_many_requests)

            print(r.json())

            # Chequeo si la petición ha ido bien    
            if r.status_code == requests.codes.ok:
                # Hago la petición para obtener los datos
                data_url = r.json()['datos']
                r_data = requests.get(data_url, params=querystring, verify=False)

                # INCONSISTENCIA DE LA API:
                # Cuando no encuentra datos en el rango seleccionado, la API devuelve
                # que el status code es 200 (todo ok) y devuelve un json con el error
                # cuando encuentra, no hay atributo estado            
                try:
                    estado = r_data.json()['estado']
                except:
                    estado = 200


                # Si ha ido bien guardo los datos
                if estado == requests.codes.ok:
                    #print(r_data.json())
                    raw_data.extend(r_data.json())
                else:
                    print(r_data.json()['descripcion'])
            else:
                print(r.json()['descripcion'])

            time.sleep(60/45)
            
    return raw_data

# %%
def serie_df(data):
    """Create a data frame with the series of daily records of a station given as a list of dictionaries"""
    # Crea un data frame con los datos diarios de una estación
    n = len(data)

    columnas = []
    for key in data[0].keys():
        columnas.append(key)

    serie = pd.DataFrame(index=np.arange(n), columns=columnas)
    serie = serie.loc[:, ['fecha', 'indicativo', 'nombre', 'provincia', 'altitud', 'prec', 'tmed', 'tmin', 'horatmin', 'tmax', 
                          'horatmax', 'dir', 'velmedia', 'racha', 'horaracha', 'sol', 'presMax', 'horaPresMax', 'presMin',
                          'horaPresMin']]

    for i in np.arange(len(data)):
        keys = list(data[i].keys())
        for key in keys:
            serie[key][i] = data[i][key]
    
    serie.fecha = pd.to_datetime(serie.fecha, yearfirst=True)
    
    return serie

# %% [markdown]
# ### 2.2 Generar series
#
# #### Definir fechas

# %%
# Definir la duración de cada periodo y calcular los periodos
step = datetime.timedelta(days=30)
periodos = generate_dates(start_date, final_date, step)
print('Nº de periodos en los que se divide el periodo de estudio: ', len(periodos))
# Out:
# Nº de periodos en los que se divide el periodo de estudio:  828

# %% [markdown]
# #### Definir las estaciones

# %%
# Definir las estaciones a extraer
if estaciones[0] == 'todas':
    stn_AEMET_sub = stn_AEMET
else:
    stn_AEMET_sub = stn_AEMET.loc[estaciones]
        
print('Nº de estaciones a extraer: ', stn_AEMET_sub.shape[0])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-36d5c760d0f9> in <module>()
#       3     stn_AEMET_sub = stn_AEMET
#       4 else:
# ----> 5     stn_AEMET_sub = stn_AEMET.loc[estaciones]
#       6
#       7 print('Nº de estaciones a extraer: ', stn_AEMET_sub.shape[0])
#
# C:\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1326         else:
#    1327             key = com._apply_if_callable(key, self.obj)
# -> 1328             return self._getitem_axis(key, axis=0)
#    1329
#    1330     def _is_scalar_access(self, key):
#
# C:\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1539                     raise ValueError('Cannot index with multidimensional key')
#    1540
# -> 1541                 return self._getitem_iterable(key, axis=axis)
#    1542
#    1543             # nested tuple slicing
#
# C:\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_iterable(self, key, axis)
#    1079     def _getitem_iterable(self, key, axis=0):
#    1080         if self._should_validate_iterable(axis):
# -> 1081             self._has_valid_type(key, axis)
#    1082
#    1083         labels = self.obj._get_axis(axis)
#
# C:\Anaconda3\lib\site-packages\pandas\core\indexing.py in _has_valid_type(self, key, axis)
#    1416
#    1417                 raise KeyError("None of [%s] are in the [%s]" %
# -> 1418                                (key, self.obj._get_axis_name(axis)))
#    1419
#    1420             return True
#
# KeyError: "None of [['2620E', '2621', '2622', '2624']] are in the [index]"

# %% [markdown]
# #### Extraer, organizar y exportar las series

# %%
# Extraer, reorganizar y exportar las series de cada una de las estaciones
for stn in stn_AEMET_sub.index[3:]:
    # Cargar la API key
    api_key = open(ruta_API).read().rstrip()
    querystring = {"api_key": api_key}
    
    # Extraer los datos
    raw_data = extract_data(stn, periodos)
    
    # Convertir los datos en numeros reales
    data = parse_data(raw_data)

    # Reorganizar la serie en forma de data frame
    serie = serie_df(data)
    
    # Exportar la serie
    serie.to_csv(ruta_series + stn + '_' + stn_AEMET_sub.loc[stn, 'nombre'] + '.csv', index=None, na_rep='NaN')
# Out:
# 5530E  -  1950-01-01T00:00:00UTC  -  1950-01-31T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/3a214d9b', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1950-01-31T00:00:00UTC  -  1950-03-02T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/00ea56e0', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1950-03-02T00:00:00UTC  -  1950-04-01T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/7c19776b', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1950-04-01T00:00:00UTC  -  1950-05-01T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/318f9fa9', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1950-05-01T00:00:00UTC  -  1950-05-31T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/2170bff4', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1950-05-31T00:00:00UTC  -  1950-06-30T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/5bd0e106', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1950-06-30T00:00:00UTC  -  1950-07-30T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/43ac0e59', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1950-07-30T00:00:00UTC  -  1950-08-29T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/642bc40d', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1950-08-29T00:00:00UTC  -  1950-09-28T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/1c598978', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1950-09-28T00:00:00UTC  -  1950-10-28T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/3ea7f861', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1950-10-28T00:00:00UTC  -  1950-11-27T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/dee9d83f', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1950-11-27T00:00:00UTC  -  1950-12-27T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/0b4e2f9b', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1950-12-27T00:00:00UTC  -  1951-01-26T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/eef9b9bf', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1951-01-26T00:00:00UTC  -  1951-02-25T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/56d3633a', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1951-02-25T00:00:00UTC  -  1951-03-27T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/5b5b2481', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1951-03-27T00:00:00UTC  -  1951-04-26T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/f0423ea3', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1951-04-26T00:00:00UTC  -  1951-05-26T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/cef6b07a', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1951-05-26T00:00:00UTC  -  1951-06-25T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/c8db2ca5', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1951-06-25T00:00:00UTC  -  1951-07-25T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/540f5941', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1951-07-25T00:00:00UTC  -  1951-08-24T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/adaf8c91', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1951-08-24T00:00:00UTC  -  1951-09-23T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/84ed6eca', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1951-09-23T00:00:00UTC  -  1951-10-23T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/76b4ca81', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1951-10-23T00:00:00UTC  -  1951-11-22T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/79304ddd', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1951-11-22T00:00:00UTC  -  1951-12-22T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/eeea2315', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1951-12-22T00:00:00UTC  -  1952-01-21T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/3923dadf', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1952-01-21T00:00:00UTC  -  1952-02-20T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/8fe36654', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1952-02-20T00:00:00UTC  -  1952-03-21T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/1494e70d', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1952-03-21T00:00:00UTC  -  1952-04-20T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/c17faedd', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1952-04-20T00:00:00UTC  -  1952-05-20T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/3747e4f7', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1952-05-20T00:00:00UTC  -  1952-06-19T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/c5e0d419', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1952-06-19T00:00:00UTC  -  1952-07-19T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/e94d2a33', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1952-07-19T00:00:00UTC  -  1952-08-18T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/331087cf', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1952-08-18T00:00:00UTC  -  1952-09-17T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/ed1746df', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1952-09-17T00:00:00UTC  -  1952-10-17T00:00:00UTC
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/750a2cae', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1952-10-17T00:00:00UTC  -  1952-11-16T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/daa7a7a7', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1952-11-16T00:00:00UTC  -  1952-12-16T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/2376eaf9', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1952-12-16T00:00:00UTC  -  1953-01-15T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/2a159423', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1953-01-15T00:00:00UTC  -  1953-02-14T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/8d4cf965', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1953-02-14T00:00:00UTC  -  1953-03-16T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/3e1c9b81', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1953-03-16T00:00:00UTC  -  1953-04-15T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/abeb767b', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1953-04-15T00:00:00UTC  -  1953-05-15T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/420c2c06', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1953-05-15T00:00:00UTC  -  1953-06-14T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/d023ac0b', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1953-06-14T00:00:00UTC  -  1953-07-14T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/b7d329a6', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1953-07-14T00:00:00UTC  -  1953-08-13T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/85624f38', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1953-08-13T00:00:00UTC  -  1953-09-12T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/b5210590', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1953-09-12T00:00:00UTC  -  1953-10-12T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/15c053e7', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1953-10-12T00:00:00UTC  -  1953-11-11T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/16342c7a', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1953-11-11T00:00:00UTC  -  1953-12-11T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/56828c2b', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1953-12-11T00:00:00UTC  -  1954-01-10T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/554d84b0', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1954-01-10T00:00:00UTC  -  1954-02-09T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/c80ea6db', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1954-02-09T00:00:00UTC  -  1954-03-11T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/3a2914d0', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1954-03-11T00:00:00UTC  -  1954-04-10T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/98e45f1a', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1954-04-10T00:00:00UTC  -  1954-05-10T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/340734ed', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1954-05-10T00:00:00UTC  -  1954-06-09T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/6ef20b0a', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1954-06-09T00:00:00UTC  -  1954-07-09T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/cff57f22', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1954-07-09T00:00:00UTC  -  1954-08-08T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/c3d4f92b', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1954-08-08T00:00:00UTC  -  1954-09-07T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/af96b747', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1954-09-07T00:00:00UTC  -  1954-10-07T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/d6f1a94d', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1954-10-07T00:00:00UTC  -  1954-11-06T00:00:00UTC
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/a14db6e5', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1954-11-06T00:00:00UTC  -  1954-12-06T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/85409fd9', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1954-12-06T00:00:00UTC  -  1955-01-05T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/67b28aa0', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1955-01-05T00:00:00UTC  -  1955-02-04T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/fbb200e9', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1955-02-04T00:00:00UTC  -  1955-03-06T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/91387411', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1955-03-06T00:00:00UTC  -  1955-04-05T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/ed5e8816', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1955-04-05T00:00:00UTC  -  1955-05-05T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/9e4467d6', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1955-05-05T00:00:00UTC  -  1955-06-04T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/c474fef9', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1955-06-04T00:00:00UTC  -  1955-07-04T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/68975a78', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1955-07-04T00:00:00UTC  -  1955-08-03T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/dc71d113', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1955-08-03T00:00:00UTC  -  1955-09-02T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/63f3b881', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1955-09-02T00:00:00UTC  -  1955-10-02T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/7a8d530f', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1955-10-02T00:00:00UTC  -  1955-11-01T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/654b1014', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1955-11-01T00:00:00UTC  -  1955-12-01T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/bf3120e3', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1955-12-01T00:00:00UTC  -  1955-12-31T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/4497fa5f', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1955-12-31T00:00:00UTC  -  1956-01-30T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/9a00f004', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1956-01-30T00:00:00UTC  -  1956-02-29T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/63a5a556', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1956-02-29T00:00:00UTC  -  1956-03-30T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/11e4a449', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1956-03-30T00:00:00UTC  -  1956-04-29T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/8aa6fb56', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1956-04-29T00:00:00UTC  -  1956-05-29T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/141d0f9d', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1956-05-29T00:00:00UTC  -  1956-06-28T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/ac156adb', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1956-06-28T00:00:00UTC  -  1956-07-28T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/a0843175', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1956-07-28T00:00:00UTC  -  1956-08-27T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/daa5b238', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1956-08-27T00:00:00UTC  -  1956-09-26T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/5c290787', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1956-09-26T00:00:00UTC  -  1956-10-26T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/1f9f5cf0', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1956-10-26T00:00:00UTC  -  1956-11-25T00:00:00UTC
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/9f9f4d16', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1956-11-25T00:00:00UTC  -  1956-12-25T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/0f167564', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1956-12-25T00:00:00UTC  -  1957-01-24T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/eaa05495', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1957-01-24T00:00:00UTC  -  1957-02-23T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/f272c7a8', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1957-02-23T00:00:00UTC  -  1957-03-25T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/2c67cacb', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1957-03-25T00:00:00UTC  -  1957-04-24T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/431716ef', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1957-04-24T00:00:00UTC  -  1957-05-24T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/78bd7dc5', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1957-05-24T00:00:00UTC  -  1957-06-23T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/8e314d6d', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1957-06-23T00:00:00UTC  -  1957-07-23T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/9ba4e38d', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1957-07-23T00:00:00UTC  -  1957-08-22T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/b7cea690', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1957-08-22T00:00:00UTC  -  1957-09-21T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/90ba8b76', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1957-09-21T00:00:00UTC  -  1957-10-21T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/974c63b7', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1957-10-21T00:00:00UTC  -  1957-11-20T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/ae6ec873', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1957-11-20T00:00:00UTC  -  1957-12-20T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/02657fb8', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1957-12-20T00:00:00UTC  -  1958-01-19T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/2b24d394', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1958-01-19T00:00:00UTC  -  1958-02-18T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/6d29a3ad', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1958-02-18T00:00:00UTC  -  1958-03-20T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/6bec8a74', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1958-03-20T00:00:00UTC  -  1958-04-19T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/74d81648', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1958-04-19T00:00:00UTC  -  1958-05-19T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/ad23118b', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1958-05-19T00:00:00UTC  -  1958-06-18T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/1379c02c', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1958-06-18T00:00:00UTC  -  1958-07-18T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/9dbca29a', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1958-07-18T00:00:00UTC  -  1958-08-17T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/5982ac83', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1958-08-17T00:00:00UTC  -  1958-09-16T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/7fd545e2', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1958-09-16T00:00:00UTC  -  1958-10-16T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/b51af64c', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1958-10-16T00:00:00UTC  -  1958-11-15T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/1a361f27', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1958-11-15T00:00:00UTC  -  1958-12-15T00:00:00UTC
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/0d78c17a', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1958-12-15T00:00:00UTC  -  1959-01-14T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/75118abb', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1959-01-14T00:00:00UTC  -  1959-02-13T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/66942bdc', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1959-02-13T00:00:00UTC  -  1959-03-15T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/a30bbeda', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1959-03-15T00:00:00UTC  -  1959-04-14T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/2745ce94', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1959-04-14T00:00:00UTC  -  1959-05-14T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/9fef4ca5', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1959-05-14T00:00:00UTC  -  1959-06-13T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/7f10eebb', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1959-06-13T00:00:00UTC  -  1959-07-13T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/4ccfc261', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1959-07-13T00:00:00UTC  -  1959-08-12T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/9019432d', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1959-08-12T00:00:00UTC  -  1959-09-11T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/233e65ff', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1959-09-11T00:00:00UTC  -  1959-10-11T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/db104df9', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1959-10-11T00:00:00UTC  -  1959-11-10T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/231740b0', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1959-11-10T00:00:00UTC  -  1959-12-10T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/8c87f554', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1959-12-10T00:00:00UTC  -  1960-01-09T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/a0680838', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1960-01-09T00:00:00UTC  -  1960-02-08T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/a9dbac85', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1960-02-08T00:00:00UTC  -  1960-03-09T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/cb66d235', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1960-03-09T00:00:00UTC  -  1960-04-08T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/138dce0e', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1960-04-08T00:00:00UTC  -  1960-05-08T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/5063da2a', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1960-05-08T00:00:00UTC  -  1960-06-07T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/7cf06d3c', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1960-06-07T00:00:00UTC  -  1960-07-07T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/4f6f35e2', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1960-07-07T00:00:00UTC  -  1960-08-06T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/9f3fda1d', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# ...
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/e96633f6', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1969-04-21T00:00:00UTC  -  1969-05-21T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/cbab8104', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1969-05-21T00:00:00UTC  -  1969-06-20T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/d86544ca', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1969-06-20T00:00:00UTC  -  1969-07-20T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/02492193', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1969-07-20T00:00:00UTC  -  1969-08-19T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/ff105ae8', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1969-08-19T00:00:00UTC  -  1969-09-18T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/25e38c04', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1969-09-18T00:00:00UTC  -  1969-10-18T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/2c1b8b37', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1969-10-18T00:00:00UTC  -  1969-11-17T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/57696194', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1969-11-17T00:00:00UTC  -  1969-12-17T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/c89beeae', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1969-12-17T00:00:00UTC  -  1970-01-16T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/9b0bbe7c', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1970-01-16T00:00:00UTC  -  1970-02-15T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/9395984a', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1970-02-15T00:00:00UTC  -  1970-03-17T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/48033527', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1970-03-17T00:00:00UTC  -  1970-04-16T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/6d7173d5', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1970-04-16T00:00:00UTC  -  1970-05-16T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/4074124f', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1970-05-16T00:00:00UTC  -  1970-06-15T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/defc212a', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1970-06-15T00:00:00UTC  -  1970-07-15T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/85de4fa7', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1970-07-15T00:00:00UTC  -  1970-08-14T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/1ffdc6cf', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1970-08-14T00:00:00UTC  -  1970-09-13T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/eb786dd4', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1970-09-13T00:00:00UTC  -  1970-10-13T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/56288e18', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1970-10-13T00:00:00UTC  -  1970-11-12T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/31774366', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1970-11-12T00:00:00UTC  -  1970-12-12T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/67a29e68', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1970-12-12T00:00:00UTC  -  1971-01-11T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/213b85db', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1971-01-11T00:00:00UTC  -  1971-02-10T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/28e5a0e9', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1971-02-10T00:00:00UTC  -  1971-03-12T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/adb93181', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1971-03-12T00:00:00UTC  -  1971-04-11T00:00:00UTC
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.', 'estado': 429}
# Límite de peticiones o caudal por minuto excedido para este usuario. Espere al siguiente minuto.
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/da8200eb', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1971-04-11T00:00:00UTC  -  1971-05-11T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/17b64299', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1971-05-11T00:00:00UTC  -  1971-06-10T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/563c6d90', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1971-06-10T00:00:00UTC  -  1971-07-10T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/339f3c98', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1971-07-10T00:00:00UTC  -  1971-08-09T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/c85c84b7', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1971-08-09T00:00:00UTC  -  1971-09-08T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/fb0257ff', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1971-09-08T00:00:00UTC  -  1971-10-08T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/4d006032', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1971-10-08T00:00:00UTC  -  1971-11-07T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/06f23296', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1971-11-07T00:00:00UTC  -  1971-12-07T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/535e12a0', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1971-12-07T00:00:00UTC  -  1972-01-06T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/a7b88dc9', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1972-01-06T00:00:00UTC  -  1972-02-05T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/65c0fb04', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1972-02-05T00:00:00UTC  -  1972-03-06T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/5945f58e', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1972-03-06T00:00:00UTC  -  1972-04-05T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/2837eef5', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1972-04-05T00:00:00UTC  -  1972-05-05T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/1932d9ef', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1972-05-05T00:00:00UTC  -  1972-06-04T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/047c9bc6', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# No hay datos que satisfagan esos criterios
#
# 5530E  -  1972-06-04T00:00:00UTC  -  1972-07-04T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/21587bb2', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
#
# 5530E  -  1972-07-04T00:00:00UTC  -  1972-08-03T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/6370f4ed', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
#
# 5530E  -  1972-08-03T00:00:00UTC  -  1972-09-02T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/594be913', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
#
# 5530E  -  1972-09-02T00:00:00UTC  -  1972-10-02T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/07e30cb6', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
# 5530E  -  1972-10-02T00:00:00UTC  -  1972-11-01T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/0ed2e75f', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
#
# 5530E  -  1972-11-01T00:00:00UTC  -  1972-12-01T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/90beb185', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
#
# 5530E  -  1972-12-01T00:00:00UTC  -  1972-12-31T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/e63e0a10', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
#
# 5530E  -  1972-12-31T00:00:00UTC  -  1973-01-30T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/e9fa4289', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
#
# 5530E  -  1973-01-30T00:00:00UTC  -  1973-03-01T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/4d505221', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
#
# 5530E  -  1973-03-01T00:00:00UTC  -  1973-03-31T00:00:00UTC
# {'descripcion': 'exito', 'estado': 200, 'datos': 'https://opendata.aemet.es/opendata/sh/f07d6577', 'metadatos': 'https://opendata.aemet.es/opendata/sh/b3aa9d28'}
